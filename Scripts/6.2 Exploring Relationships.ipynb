# %% [markdown]
# # 1. Import libraries and Data

# %% [markdown]
# # 2. Correlation

# %% [markdown]
# # 3. Scatterplots

# %% [markdown]
# # 4. Pair Plots

# %% [markdown]
# # 5. Categorical Plots

# %% [markdown]
# # 6. Questions

# %% [markdown]
# # 7. Hypothesis

# %% [markdown]
# # 8. Export Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
matplotlib.__version__
# Out:
# '3.7.0'

# %%
# %matplotlib inline

# %%
#create string for the path 

path = r'C:\Users\kilia\OneDrive\CareerFoundry\Projects\Data Immersion Course\Achievement 6\Berlin_AirBnB Analysis\02 Data\Prepared Data'
path1 =r'C:\Users\kilia\OneDrive\CareerFoundry\Projects\Data Immersion Course\Achievement 6\Berlin_AirBnB Analysis\04 Analysis\Visualizations'

# %%
# define column types
dtype_options = {'15':str}

# %%
df = pd.read_csv(os.path.join(path,'2.0 Airbnb_cleaned.csv'), index_col = 0, dtype=dtype_options)
# Out:
# C:\Users\kilia\AppData\Local\Temp\ipykernel_301612\842630719.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path,'2.0 Airbnb_cleaned.csv'), index_col = 0, dtype=dtype_options)

# %%
# Display all columns 

pd.set_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#        Review ID Review_Date  Reviewer ID  \
# index
# 0       58660447  2016-01-03     14876562
# 2       58663795  2016-01-03     49367757
# 3       59003619  2016-01-05     46694292
# 4       66845661  2016-03-25     54542819
# 5       67969785  2016-04-01     35352843
# 6       68816282  2016-04-06     48006291
# 7       69289363  2016-04-10     63759402
# 8       69780867  2016-04-13     53960263
# 9       70426866  2016-04-17     26184931
# 10      78320875  2016-06-06     12388715
#
#                                           Rating_Comment  Listing ID  \
# index
# 0      Very nice, clean appartement! Josh was really ...    10002699
# 2      Aki is really nice and friendly. We had an ama...    10006647
# 3      Aki is a very nice dude with a clean place in ...    10006647
# 4      Aki's place was easy to find and located in th...    10006647
# 5      We had to wait 30mins for Aki to arrive but ot...    10006647
# 6      Great room, very comfortable and clean. Aki an...    10006647
# 7      Aki was really friendly and available giving u...    10006647
# 8      Aki es sin duda el mejor host q uno puede tene...    10006647
# 9      We did not meer Aki, but we did meet FabiÃ¡n, ...    10006647
# 10     Aki was an awesome host in Berlin. We got alon...    10006647
#
#                          Listing Name   Host ID  Host Since  \
# index
# 0      Trendy and peaceful Kreuzkölln  44696672  2015-09-20
# 2         Very central and very quite  40791092  2015-08-07
# 3         Very central and very quite  40791092  2015-08-07
# 4         Very central and very quite  40791092  2015-08-07
# 5         Very central and very quite  40791092  2015-08-07
# 6         Very central and very quite  40791092  2015-08-07
# 7         Very central and very quite  40791092  2015-08-07
# 8         Very central and very quite  40791092  2015-08-07
# 9         Very central and very quite  40791092  2015-08-07
# 10        Very central and very quite  40791092  2015-08-07
#
#        Host Response Time  Host Response Rate  Is Superhost Neighborhood  \
# index
# 0                     NaN                 NaN         False     Neukölln
# 2      within a few hours               100.0         False        Mitte
# 3      within a few hours               100.0         False        Mitte
# 4      within a few hours               100.0         False        Mitte
# 5      within a few hours               100.0         False        Mitte
# 6      within a few hours               100.0         False        Mitte
# 7      within a few hours               100.0         False        Mitte
# 8      within a few hours               100.0         False        Mitte
# 9      within a few hours               100.0         False        Mitte
# 10     within a few hours               100.0         False        Mitte
#
#       Neighborhood Group    City Postal Code  Country  Latitude  Longitude  \
# index
# 0               Neukölln  Berlin     12047.0  Germany  52.49234   13.42994
# 2                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 3                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 4                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 5                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 6                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 7                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 8                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 9                  Mitte  Berlin     10178.0  Germany  52.52134   13.41866
# 10                 Mitte  Berlin     10178.0  Germany  52.52134   13.41866
#
#       Property Type        Room Type  Accomodates  Bathrooms  Bedrooms  Beds  \
# index
# 0         Apartment  Entire home/apt            4        1.0       2.0   2.0
# 2         Apartment     Private room            2        1.0       1.0   1.0
# 3         Apartment     Private room            2        1.0       1.0   1.0
# 4         Apartment     Private room            2        1.0       1.0   1.0
# 5         Apartment     Private room            2        1.0       1.0   1.0
# 6         Apartment     Private room            2        1.0       1.0   1.0
# 7         Apartment     Private room            2        1.0       1.0   1.0
# 8         Apartment     Private room            2        1.0       1.0   1.0
# 9         Apartment     Private room            2        1.0       1.0   1.0
# 10        Apartment     Private room            2        1.0       1.0   1.0
#
#        Price  Guests Included  Min Nights  Reviews First Review Last Review  \
# index
# 0       60.0                1           1        1   2016-01-03  2016-01-03
# 2       35.0                1           1       20   2016-01-03  2017-02-12
# 3       35.0                1           1       20   2016-01-03  2017-02-12
# 4       35.0                1           1       20   2016-01-03  2017-02-12
# 5       35.0                1           1       20   2016-01-03  2017-02-12
# 6       35.0                1           1       20   2016-01-03  2017-02-12
# 7       35.0                1           1       20   2016-01-03  2017-02-12
# 8       35.0                1           1       20   2016-01-03  2017-02-12
# 9       35.0                1           1       20   2016-01-03  2017-02-12
# 10      35.0                1           1       20   2016-01-03  2017-02-12
#
#        Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# index
# 0               100.0              8.0                10.0             6.0
# 2                92.0              9.0                 8.0             9.0
# 3                92.0              9.0                 8.0             9.0
# 4                92.0              9.0                 8.0             9.0
# 5                92.0              9.0                 8.0             9.0
# 6                92.0              9.0                 8.0             9.0
# 7                92.0              9.0                 8.0             9.0
# 8                92.0              9.0                 8.0             9.0
# 9                92.0              9.0                 8.0             9.0
# 10               92.0              9.0                 8.0             9.0
#
#        Communication Rating  Location Rating  Value Rating  Instant Bookable
# index
# 0                      10.0             10.0          10.0             False
# 2                      10.0             10.0           9.0             False
# 3                      10.0             10.0           9.0             False
# 4                      10.0             10.0           9.0             False
# 5                      10.0             10.0           9.0             False
# 6                      10.0             10.0           9.0             False
# 7                      10.0             10.0           9.0             False
# 8                      10.0             10.0           9.0             False
# 9                      10.0             10.0           9.0             False
# 10                     10.0             10.0           9.0             False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452805 entries, 0 to 456960
# Data columns (total 38 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Review ID             452805 non-null  int64
#  1   Review_Date           452805 non-null  object
#  2   Reviewer ID           452805 non-null  int64
#  3   Rating_Comment        452597 non-null  object
#  4   Listing ID            452805 non-null  int64
#  5   Listing Name          452622 non-null  object
#  6   Host ID               452805 non-null  int64
#  7   Host Since            452767 non-null  object
#  8   Host Response Time    396841 non-null  object
#  9   Host Response Rate    396841 non-null  float64
#  10  Is Superhost          452805 non-null  bool
#  11  Neighborhood          452805 non-null  object
#  12  Neighborhood Group    452805 non-null  object
#  13  City                  452805 non-null  object
#  14  Postal Code           445219 non-null  object
#  15  Country               452805 non-null  object
#  16  Latitude              452805 non-null  float64
#  17  Longitude             452805 non-null  float64
#  18  Property Type         452805 non-null  object
#  19  Room Type             452805 non-null  object
#  20  Accomodates           452805 non-null  int64
#  21  Bathrooms             451868 non-null  float64
#  22  Bedrooms              452096 non-null  float64
#  23  Beds                  452733 non-null  float64
#  24  Price                 452805 non-null  float64
#  25  Guests Included       452805 non-null  int64
#  26  Min Nights            452805 non-null  int64
#  27  Reviews               452805 non-null  int64
#  28  First Review          452805 non-null  object
#  29  Last Review           452805 non-null  object
#  30  Overall Rating        452240 non-null  float64
#  31  Accuracy Rating       452207 non-null  float64
#  32  Cleanliness Rating    452209 non-null  float64
#  33  Checkin Rating        452186 non-null  float64
#  34  Communication Rating  452203 non-null  float64
#  35  Location Rating       452184 non-null  float64
#  36  Value Rating          452183 non-null  float64
#  37  Instant Bookable      452805 non-null  bool
# dtypes: bool(2), float64(14), int64(8), object(14)
# memory usage: 128.7+ MB

# %%
df.columns
# Out:
# Index(['Review ID', 'Review_Date', 'Reviewer ID', 'Rating_Comment',
#        'Listing ID', 'Listing Name', 'Host ID', 'Host Since',
#        'Host Response Time', 'Host Response Rate', 'Is Superhost',
#        'Neighborhood', 'Neighborhood Group', 'City', 'Postal Code', 'Country',
#        'Latitude', 'Longitude', 'Property Type', 'Room Type', 'Accomodates',
#        'Bathrooms', 'Bedrooms', 'Beds', 'Price', 'Guests Included',
#        'Min Nights', 'Reviews', 'First Review', 'Last Review',
#        'Overall Rating', 'Accuracy Rating', 'Cleanliness Rating',
#        'Checkin Rating', 'Communication Rating', 'Location Rating',
#        'Value Rating', 'Instant Bookable'],
#       dtype='object')

# %%
#Create Subset with without variables not needed in exploratory analysis

sub = df[['Price','Host Response Rate', 'Accomodates', 
          'Bathrooms', 'Bedrooms', 'Beds', 'Guests Included',
          'Min Nights', 'Reviews', 'Overall Rating', 'Accuracy Rating', 
          'Cleanliness Rating', 'Checkin Rating','Communication Rating', 
          'Location Rating', 'Value Rating', 'Is Superhost', 'Room Type', 'Instant Bookable']]

# %%
sub.head(5)
# Out:
#        Price  Host Response Rate  Accomodates  Bathrooms  Bedrooms  Beds  \
# index
# 0       60.0                 NaN            4        1.0       2.0   2.0
# 2       35.0               100.0            2        1.0       1.0   1.0
# 3       35.0               100.0            2        1.0       1.0   1.0
# 4       35.0               100.0            2        1.0       1.0   1.0
# 5       35.0               100.0            2        1.0       1.0   1.0
#
#        Guests Included  Min Nights  Reviews  Overall Rating  Accuracy Rating  \
# index
# 0                    1           1        1           100.0              8.0
# 2                    1           1       20            92.0              9.0
# 3                    1           1       20            92.0              9.0
# 4                    1           1       20            92.0              9.0
# 5                    1           1       20            92.0              9.0
#
#        Cleanliness Rating  Checkin Rating  Communication Rating  \
# index
# 0                    10.0             6.0                  10.0
# 2                     8.0             9.0                  10.0
# 3                     8.0             9.0                  10.0
# 4                     8.0             9.0                  10.0
# 5                     8.0             9.0                  10.0
#
#        Location Rating  Value Rating  Is Superhost        Room Type  \
# index
# 0                 10.0          10.0         False  Entire home/apt
# 2                 10.0           9.0         False     Private room
# 3                 10.0           9.0         False     Private room
# 4                 10.0           9.0         False     Private room
# 5                 10.0           9.0         False     Private room
#
#        Instant Bookable
# index
# 0                 False
# 2                 False
# 3                 False
# 4                 False
# 5                 False

# %% [markdown]
# ### I excluded all ID's and dates for the correlation plot/matrix, also all geographical columns like postal code and neigborhood.

# %% [markdown]
# ## Correlation

# %%
# Create correlation matrix 

sub.corr()
# Out:
# C:\Users\kilia\AppData\Local\Temp\ipykernel_301612\579265902.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sub.corr()
#                          Price  Host Response Rate  Accomodates  Bathrooms  \
# Price                 1.000000            0.032566     0.418571   0.251857
# Host Response Rate    0.032566            1.000000     0.060079   0.042988
# Accomodates           0.418571            0.060079     1.000000   0.357145
# Bathrooms             0.251857            0.042988     0.357145   1.000000
# Bedrooms              0.369564            0.014100     0.685195   0.385039
# Beds                  0.340210            0.056072     0.848317   0.331649
# Guests Included       0.354972            0.055911     0.643727   0.314110
# Min Nights           -0.013587           -0.047677    -0.032415  -0.026787
# Reviews              -0.001638            0.135440     0.048955  -0.004209
# Overall Rating        0.002060            0.058902    -0.141107   0.029577
# Accuracy Rating      -0.025927            0.065401    -0.104675   0.005274
# Cleanliness Rating    0.042170            0.105106    -0.067152   0.014431
# Checkin Rating       -0.010950            0.096304    -0.064838   0.005896
# Communication Rating -0.013064            0.105512    -0.083654   0.010109
# Location Rating       0.039740            0.016188    -0.118656  -0.011109
# Value Rating         -0.099578            0.034404    -0.231850  -0.011684
# Is Superhost          0.023793            0.200720    -0.046219   0.043372
# Instant Bookable      0.032370            0.169040     0.130679   0.029642
#
#                       Bedrooms      Beds  Guests Included  Min Nights  \
# Price                 0.369564  0.340210         0.354972   -0.013587
# Host Response Rate    0.014100  0.056072         0.055911   -0.047677
# Accomodates           0.685195  0.848317         0.643727   -0.032415
# Bathrooms             0.385039  0.331649         0.314110   -0.026787
# Bedrooms              1.000000  0.644349         0.525374   -0.004049
# Beds                  0.644349  1.000000         0.550615   -0.015473
# Guests Included       0.525374  0.550615         1.000000   -0.002671
# Min Nights           -0.004049 -0.015473        -0.002671    1.000000
# Reviews              -0.003266  0.027769         0.044571   -0.062996
# Overall Rating       -0.025231 -0.152827        -0.056440    0.006565
# Accuracy Rating      -0.025643 -0.116161        -0.044988    0.004401
# Cleanliness Rating   -0.000534 -0.071512         0.000645    0.012411
# Checkin Rating       -0.017308 -0.062242        -0.033898   -0.001866
# Communication Rating -0.016822 -0.098573        -0.040116    0.018662
# Location Rating      -0.058561 -0.137550        -0.087333   -0.034446
# Value Rating         -0.087478 -0.211868        -0.132149   -0.019144
# Is Superhost          0.009971 -0.048326         0.019539   -0.037492
# Instant Bookable      0.025290  0.093474         0.113409   -0.086885
#
#                        Reviews  Overall Rating  Accuracy Rating  \
# Price                -0.001638        0.002060        -0.025927
# Host Response Rate    0.135440        0.058902         0.065401
# Accomodates           0.048955       -0.141107        -0.104675
# Bathrooms            -0.004209        0.029577         0.005274
# Bedrooms             -0.003266       -0.025231        -0.025643
# Beds                  0.027769       -0.152827        -0.116161
# Guests Included       0.044571       -0.056440        -0.044988
# Min Nights           -0.062996        0.006565         0.004401
# Reviews               1.000000       -0.034144         0.084831
# Overall Rating       -0.034144        1.000000         0.669785
# Accuracy Rating       0.084831        0.669785         1.000000
# Cleanliness Rating    0.092296        0.654325         0.521483
# Checkin Rating        0.065122        0.519039         0.492811
# Communication Rating  0.047754        0.572195         0.525446
# Location Rating       0.118655        0.324368         0.273257
# Value Rating          0.001511        0.660852         0.510059
# Is Superhost          0.228892        0.439862         0.355335
# Instant Bookable      0.158507       -0.122943        -0.083186
#
#                       Cleanliness Rating  Checkin Rating  \
# Price                           0.042170       -0.010950
# Host Response Rate              0.105106        0.096304
# Accomodates                    -0.067152       -0.064838
# Bathrooms                       0.014431        0.005896
# Bedrooms                       -0.000534       -0.017308
# Beds                           -0.071512       -0.062242
# Guests Included                 0.000645       -0.033898
# Min Nights                      0.012411       -0.001866
# Reviews                         0.092296        0.065122
# Overall Rating                  0.654325        0.519039
# Accuracy Rating                 0.521483        0.492811
# Cleanliness Rating              1.000000        0.355695
# Checkin Rating                  0.355695        1.000000
# Communication Rating            0.375459        0.609056
# Location Rating                 0.213781        0.216309
# Value Rating                    0.478660        0.388760
# Is Superhost                    0.380062        0.292221
# Instant Bookable               -0.056532       -0.054282
#
#                       Communication Rating  Location Rating  Value Rating  \
# Price                            -0.013064         0.039740     -0.099578
# Host Response Rate                0.105512         0.016188      0.034404
# Accomodates                      -0.083654        -0.118656     -0.231850
# Bathrooms                         0.010109        -0.011109     -0.011684
# Bedrooms                         -0.016822        -0.058561     -0.087478
# Beds                             -0.098573        -0.137550     -0.211868
# Guests Included                  -0.040116        -0.087333     -0.132149
# Min Nights                        0.018662        -0.034446     -0.019144
# Reviews                           0.047754         0.118655      0.001511
# Overall Rating                    0.572195         0.324368      0.660852
# Accuracy Rating                   0.525446         0.273257      0.510059
# Cleanliness Rating                0.375459         0.213781      0.478660
# Checkin Rating                    0.609056         0.216309      0.388760
# Communication Rating              1.000000         0.222851      0.414397
# Location Rating                   0.222851         1.000000      0.277446
# Value Rating                      0.414397         0.277446      1.000000
# Is Superhost                      0.319446         0.186485      0.359550
# Instant Bookable                 -0.073034        -0.048133     -0.106073
#
#                       Is Superhost  Instant Bookable
# Price                     0.023793          0.032370
# Host Response Rate        0.200720          0.169040
# Accomodates              -0.046219          0.130679
# Bathrooms                 0.043372          0.029642
# Bedrooms                  0.009971          0.025290
# Beds                     -0.048326          0.093474
# Guests Included           0.019539          0.113409
# Min Nights               -0.037492         -0.086885
# Reviews                   0.228892          0.158507
# Overall Rating            0.439862         -0.122943
# Accuracy Rating           0.355335         -0.083186
# Cleanliness Rating        0.380062         -0.056532
# Checkin Rating            0.292221         -0.054282
# Communication Rating      0.319446         -0.073034
# Location Rating           0.186485         -0.048133
# Value Rating              0.359550         -0.106073
# Is Superhost              1.000000         -0.014557
# Instant Bookable         -0.014557          1.000000

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(15,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) 
# The `annot` argument allows the plot to place the correlation coefficients onto the heatmap.
plt.title('Correlation Heatmap')
plt.savefig(os.path.join(path1, 'Heatmap_Correlation'),bbox_inches='tight', pad_inches=0.1)
# Out:
# C:\Users\kilia\AppData\Local\Temp\ipykernel_301612\731710110.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sns.heatmap(sub.corr(), annot = True, ax = ax)

# %% [markdown]
# ### - Overall we can see low correlation on many variables.
# ### - The ones that stand out are the rating values because they are all together considered in the overall rating. Whats interesting is that the location rating might has the lowest weight in the overall rating. Also isnt as strongly correlated to the other ratings.
# ### - The "accomodation features" are also naturaly correlated. If I have more bedrooms and beds I also can accomodate more people and vise versa. Also it's higly likely that there are more bathrooms for three bedrooms than for a single bedroom.
# ### - There is negative correlation between value rating and accomodates.
# ### - There is a postive correlation between is superhost and overall rating
# ### - strongest positive correlations: accomodates/beds,bedrooms,guest included and overall rating/value rating, accuracy rating, cleanliness rating
# ### - strongest negative correlations: value rating/accomodates, beds and overall rating/accomodates, beds

# %% [markdown]
# ## Scatterplots

# %%
# Create a scatterplot for strong correlated variables 

sns.lmplot(x = 'Accomodates', y = 'Beds', data = df)
plt.title('Relationship Accomodates/Beds')
plt.savefig(os.path.join(path1, 'Scatter_Accomodates-Beds'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# #### As expected there is some correlation, the outlier values could be explained due to wrong listing information

# %%
# Create a scatterplot for strong correlated variables 

sns.lmplot(x = 'Accomodates', y = 'Bedrooms', data = df)
plt.title('Relationship Accomodates/Bedrooms')
plt.savefig(os.path.join(path1, 'Scatter_Accomodates-Bedrooms'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# #### As expected there is some correlation, the outlier values could be explained due to wrong listing information

# %%
# Create a scatterplot for strong correlated variables 

sns.lmplot(x = 'Overall Rating', y = 'Value Rating', data = df)
plt.title('Relationship Overall Rating/Value Rating')
plt.savefig(os.path.join(path1, 'Scatter_Overall Rating-Value Rating'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### The value rating has a strong positive relationship to the overall rating as expected. The value rating has a lot of weight in the overall rating.

# %%
# Create a scatterplot for strong correlated variables 

sns.lmplot(x = 'Value Rating', y = 'Accomodates', data = df)
plt.title('Relationship Value Rating/Accomodates')
plt.savefig(os.path.join(path1, 'Scatter_Overall Rating-Accomodates'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### This scatterplot suggests that it is more likely to get good value ratings if the listing can accomodate more people. This could also be due to luxury listings are usually bigger.

# %%
# Create a scatterplot for strong correlated variables 

sns.lmplot(x = 'Overall Rating', y = 'Beds', data = df)
plt.title('Relationship Overall Rating/Beds')
plt.savefig(os.path.join(path1, 'Scatter_Beds-Overall Rating'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### It looks like it is more likely to get a good overall rating if the accomodation has a lot of beds. This could be due to luxury accomodations having more beds/bedrooms in general and those get better ratings. I'll look into the price/overall rating relationship to get an idea.

# %%
# Create a scatterplot for strong correlated variables 

sns.lmplot(x = 'Overall Rating', y = 'Is Superhost', data = df)
plt.title('Relationship Overall Rating/Is Superhost')
plt.savefig(os.path.join(path1, 'Scatter_IsSuperhost-Overall Rating'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### Better overall rating if the host is a superhost

# %%
# Create a scatterplot to look into price rating relationship

sns.lmplot(x = 'Overall Rating', y = 'Price', data = df)

# %%
# Create subset with only prices up to 500

subset_price = df[df['Price'] < 500]

# %%
# Create a scatterplot on the subset

sns.lmplot(x = 'Overall Rating', y = 'Price', data = subset_price)
plt.title('Relationship Overall Rating/Price')
plt.savefig(os.path.join(path1, 'Scatter_Price-Overall Rating'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### Price might be an good indicator for a good stay/good review. If you pay above 200 euro per night it is highly likely that the accomodation will be good.

# %% [markdown]
# ## Pair plots

# %%
# Create subset with relevant variables for pair plot

sub_2 = df[['Accomodates', 'Bathrooms', 'Bedrooms', 'Beds', 'Overall Rating', 'Value Rating']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)
plt.savefig(os.path.join(path1, 'Pair_Plot_without_price'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### I want to futher explore the relationship between beds and overall rating.

# %%
# Create subset with relevant variables for pair plot

sub_price = df[df['Price'] < 500][['Price','Accomodates', 'Bathrooms', 'Bedrooms', 'Beds', 'Overall Rating', 'Value Rating']]

# %%
# Create a pair plot with price column filtered for prices under 500 

g = sns.pairplot(sub_price)
plt.savefig(os.path.join(path1, 'Pair_plot_with_price'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### I want to further explore the relationship between price and overall rating. I want to know which price group has the best overall rating and is affordable for the majority of people in western countries.

# %% [markdown]
# ## Categorical Plots

# %%
# Create histogram for prices

sns.histplot(subset_price['Price'], bins = 50, kde = True)
plt.title('Histogramm Prices')
plt.savefig(os.path.join(path1, 'Histo_Price'),bbox_inches='tight', pad_inches=0.1)

# %%
# Group the price data 

df.loc[df['Price'] < 20, 'Price category'] = 'Low price'

# %%
df.loc[(df['Price'] >= 20) & (df['Price'] < 100), 'Price category'] = 'Middle price'

# %%
df.loc[df['Price'] >= 100, 'Price category'] = 'High Price'

# %%
df['Price category'].value_counts()
# Out:
# Middle price    377154
# High Price       68622
# Low price         7029
# Name: Price category, dtype: int64

# %%
df['Price category'].isnull().sum()
# Out:
# 0

# %%
377154+68622+7029
# Out:
# 452805

# %%
# Create subset with prices under 500
sub_price = df[df['Price'] < 500]

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="Overall Rating", y="Price", hue="Price category", data=sub_price, height=6, aspect=2)
plt.xticks(rotation=45)
plt.title('Relationship Overall Rating/Price categorized by Price')
plt.savefig(os.path.join(path1, 'Price-Overall_Rating_grouped by prices'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### It is clear that price and overall rating are in a positive relationship. Above 100euro per night the chance to get a bad accomodation is relatively small. Most overall ratings are above 80 if above 100euro per night.

# %%
sns.histplot(df['Overall Rating'], bins = 40, kde = True)
plt.title('Histogramm Overall Ratings')
plt.savefig(os.path.join(path1, 'Histo_Overall-Ratings'),bbox_inches='tight', pad_inches=0.1)

# %%
# Group the Overall rating 

df.loc[df['Overall Rating'] < 50, 'Rating Category'] = 'Bad Rating'

# %%
df.loc[(df['Overall Rating'] >= 50) & (df['Overall Rating'] < 90), 'Rating Category'] = 'Moderate Rating'

# %%
df.loc[df['Overall Rating'] >= 90, 'Rating Category'] = 'Good Rating'

# %%
df['Rating Category'].value_counts(dropna=False)
# Out:
# Good Rating        400176
# Moderate Rating     51973
# NaN                   565
# Bad Rating             91
# Name: Rating Category, dtype: int64

# %%
df['Rating Category'].isnull().sum()
# Out:
# 565

# %%
# Convert NA to No Rating

df['Rating Category'] = df['Rating Category'].fillna('No Rating')

# %%
# Create categorical plot with rating category

sns.set(style="ticks")
g = sns.catplot(x="Overall Rating", y="Beds", hue="Rating Category", data=df, height=6, aspect=2)
plt.xticks(rotation=45)
plt.title('Relationship Overall Rating/Beds categorized by Rating Categorys')
plt.savefig(os.path.join(path1, 'Beds-Overall_Rating_grouped by ratings'),bbox_inches='tight', pad_inches=0.1)

# %%
# Create subset with beds under 5 

sub_beds = df[df['Beds'] <= 5]

# %%
sns.histplot(sub_beds['Beds'], bins = 5, kde = True)
# Out:
# <Axes: xlabel='Beds', ylabel='Count'>

# %%
# Group accomodation  size with number of beds

df.loc[df['Beds'] <= 1, 'Accomodation Size'] = 'Single Accomodation'

# %%
df.loc[df['Beds'] == 2, 'Accomodation Size'] = 'Couple Accomodation'

# %%
df.loc[(df['Beds'] >=3) & (df['Beds'] <=5), 'Accomodation Size'] = 'Family Accomodation'

# %%
df.loc[df['Beds'] > 5, 'Accomodation Size'] = 'Big Group Accomodation'

# %%
df['Accomodation Size'].value_counts(dropna=False)
# Out:
# Single Accomodation       251599
# Couple Accomodation       110823
# Family Accomodation        71847
# Big Group Accomodation     18464
# NaN                           72
# Name: Accomodation Size, dtype: int64

# %%
df['Accomodation Size'].isnull().sum()
# Out:
# 72

# %%
# Create categorical plot with rating category

sns.set(style="ticks")
g = sns.catplot(x="Overall Rating", y="Beds", hue="Accomodation Size", data=df, height=6, aspect=2)
plt.xticks(rotation=45)
plt.title('Relationship Overall Rating/Beds categorized by Accomodation Size')
plt.savefig(os.path.join(path1, 'Beds-Overall_Rating_grouped by accomodation size'),bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### There clearly is a positive relationship between the amount of beds and the overall rating. This could be due to luxury listings having more rooms and therefore more beds.

# %% [markdown]
# ## Questions:

# %% [markdown]
# ### Are the ratings from Superhosts higher in general?

# %% [markdown]
# #### Ratings from superhosts are higer in general. Avg Rating from Superhost 96.84, average rating from non superhost 92.92.

# %%
# Average Overall rating for Superhost is TRUE

df.loc[df['Is Superhost'] == True, 'Overall Rating'].mean()
# Out:
# 96.84650623369093

# %%
# Average Overall rating for Superhost is FALSE

df.loc[df['Is Superhost'] == False, 'Overall Rating'].mean()
# Out:
# 92.92470243196405

# %% [markdown]
# ### Are there certain criteria that are outstanding on listings with very good ratings?

# %% [markdown]
# #### The amount of accomodates, beds, bedrooms and bathrooms has a positive relationship to the overall rating. Listings with higher amount of beds etc. showing better ratings in general.

# %% [markdown]
# ### Is there a correlation between the overall rating and the price?

# %% [markdown]
# #### It is clear that price and overall rating are in a positive relationship. Above 100euro per night the chance to get a bad accomodation is relatively small. Most overall ratings are above 80 if above 100euro per night.

# %% [markdown]
# ## Hypothesis:

# %% [markdown]
# #### Alternative Hypothesis: If the price of an Airbnb listing is above 100 euros per night, it is more likely to have a good overall rating.
#
# #### Null Hypothesis: There is no significant relationship between the price of an Airbnb listing above 100 euros per night and its overall rating.

# %% [markdown]
# #### Alternative Hypothesis: The greater the number of beds in an Airbnb listing, the higher the overall rating.
#
# #### Null Hypothesis: There is no significant relationship between the number of beds in an Airbnb listing and the overall rating.

# %% [markdown]
# ## Export Dataset

# %%
# Export Dataset with categorical columns 

df.to_csv(os.path.join(path,'3.0 AirBnB_categorical columns.csv'))

# %%
df.to_excel(os.path.join(path,'3.0 AirBnB_categorical columns_excelformat.xlsx'), index= False)
